# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\_PROJECT_\Exploratory Data Analysis\globalterrorism.csv', encoding='ISO-8859-1')
df.head()
# Out:
# C:\Users\sherm\AppData\Local\Temp\ipykernel_41752\3184162655.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\_PROJECT_\Exploratory Data Analysis\globalterrorism.csv', encoding='ISO-8859-1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505650
# std    1.325955e+09      13.259430       3.388303       8.814043
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
print("Data Overview:")
df.info()
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
print("\nSample Data:")
df.head()
# Out:
# Sample Data:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
categorical_columns = ['country', 'region', 'attacktype1_txt']

for col in categorical_columns:
    unique_values = df[col].unique()
    print(f"\nUnique values in {col}:")
    print(unique_values)
# Out:
# Unique values in country:
# [  58  130  160   78  101  217  218   98  499   65   83  222  362  199
#   102  185   30   60   11  110   96  209  158   94  603   45   26  145
#   142   21   38   14  153  230  198   49  406   36   97  161  201  156
#   106  155   15  236   92   69  428   31  604  605  162    6   61  205
#    87  195  136   53  138    4  159   43   88  235   59  144  121  178
#    29  100   42  377    7  200  184  215  183  104   95  182  203  186
#   139   17  147   20  207   19    8  128  173   56   93  124  403  359
#    55  349   86  137  208  213  151  111   72  113   18   89  174  231
#    84   80  532   22   81  127  221    5   41  176   57  164   32  196
#   197  116   91   70   66   33  143  166  146  141  204   68   67   76
#   122  129   90  108  157   44  112   47  123   75  228  168  177   37
#    51   50   74   16  119  115   34  214  132   12  167   99  103   10
#    28   62  202  120  219  109   64  223   46   23  179  118  226   35
# ...

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.countplot(data=df, x='iyear')
plt.xticks(rotation=-270)
plt.title('Terrorist Attacks by Year')
plt.plot()
# Out:
# []

# %%
# Distribution of attack types
# plt.subplot(2, 2, 2)
sns.countplot(data=df, y='attacktype1_txt', order=df['attacktype1_txt'].value_counts().index)
plt.title('Distribution of Attack Types')
plt.show()

# %%
sns.countplot(data=df, y='region_txt', order=df['region_txt'].value_counts().index)
plt.title('Number of Attacks in Different Regions')
plt.show()

# %%
sns.boxplot(data=df, x='attacktype1_txt', y='nkill')
plt.xticks(rotation=45)
plt.title('Number of Casualties by Attack Type')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='imonth')
plt.title('Distribution of Terrorist Attacks by Month')
plt.xlabel('Month')
plt.ylabel('Number of Attacks')
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='success')
plt.title('Distribution of Attack Success/Failure')
plt.xlabel('Attack Success/Failure')
plt.ylabel('Number of Attacks')
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='nkill', bins=30, kde=True)
plt.title('Histogram of Casualties')
plt.xlabel('Number of Casualties')
plt.ylabel('Number of Attacks')
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %%
plt.figure(figsize=(10, 6))
top_industries = df['targtype1_txt'].value_counts().head(10)
sns.barplot(x=top_industries, y=top_industries.index)
plt.title('Top 10 Targeted Industries')
plt.xlabel('Number of Attacks')
plt.ylabel('Industry')
# Out:
# Text(0, 0.5, 'Industry')
